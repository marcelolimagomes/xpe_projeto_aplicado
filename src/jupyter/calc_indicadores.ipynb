# %%
# Path para diretório raiz do projeto
import sys
sys.path.insert(0, sys.path[0].removesuffix("/src/jupyter"))

import pandas as pd
import src.utils as utils

# %%
data_file_list = utils.get_data_files()

for data_file in data_file_list:
	data = pd.read_csv(data_file, sep=';')
	if data.shape[0] > 0:
		data = utils.calc_ema_periods(data, periods_of_time=[200], close_price='adj_close', diff_price=True)
		data = utils.calc_ema_periods(data, periods_of_time=[200], close_price='close', diff_price=True)
		data = utils.calc_RSI(data, close_price='adj_close')
		#data.dropna(inplace=True)
		data = data.round(2)
		data.to_csv(data_file, sep=';', index=False)
		print(f'Ticker: {data.tail(1).ticker.values[0]} - Shape {data.shape}')
		data.info()
# Out:
# Ticker: POMO4.SA - Shape (6007, 15)
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6007 entries, 0 to 6006
# Data columns (total 15 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   s_open_time              6007 non-null   object
#  1   open_time                6007 non-null   int64
#  2   ticker                   6007 non-null   object
#  3   open                     6007 non-null   float64
#  4   high                     6007 non-null   float64
#  5   low                      6007 non-null   float64
#  6   close                    6007 non-null   float64
#  7   adj_close                6007 non-null   float64
#  8   volume                   6007 non-null   int64
#  9   type                     6007 non-null   object
#  10  ema_adj_close_200p       5808 non-null   float32
#  11  ema_adj_close_200p_diff  5808 non-null   float32
#  12  ema_close_200p           5808 non-null   float32
#  13  ema_close_200p_diff      5808 non-null   float32
#  14  rsi                      5993 non-null   float64
# dtypes: float32(4), float64(6), int64(2), object(3)
# memory usage: 610.2+ KB
# Ticker: RZAK11.SA - Shape (728, 15)
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 728 entries, 0 to 727
# Data columns (total 15 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   s_open_time              728 non-null    object
#  1   open_time                728 non-null    int64
#  2   ticker                   728 non-null    object
#  3   open                     728 non-null    float64
#  4   high                     728 non-null    float64
#  5   low                      728 non-null    float64
#  6   close                    728 non-null    float64
#  7   adj_close                728 non-null    float64
#  8   volume                   728 non-null    int64
#  9   type                     728 non-null    object
#  10  ema_adj_close_200p       529 non-null    float32
#  11  ema_adj_close_200p_diff  529 non-null    float32
#  12  ema_close_200p           529 non-null    float32
#  13  ema_close_200p_diff      529 non-null    float32
#  14  rsi                      714 non-null    float64
# dtypes: float32(4), float64(6), int64(2), object(3)
# memory usage: 74.1+ KB
# Ticker: NGRD3.SA - Shape (732, 15)
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 732 entries, 0 to 731
# Data columns (total 15 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   s_open_time              732 non-null    object
#  1   open_time                732 non-null    int64
#  2   ticker                   732 non-null    object
#  3   open                     732 non-null    float64
#  4   high                     732 non-null    float64
#  5   low                      732 non-null    float64
#  6   close                    732 non-null    float64
#  7   adj_close                732 non-null    float64
#  8   volume                   732 non-null    int64
#  9   type                     732 non-null    object
#  10  ema_adj_close_200p       533 non-null    float32
#  11  ema_adj_close_200p_diff  533 non-null    float32
#  12  ema_close_200p           533 non-null    float32
#  13  ema_close_200p_diff      533 non-null    float32
#  14  rsi                      718 non-null    float64
# dtypes: float32(4), float64(6), int64(2), object(3)
# memory usage: 74.5+ KB
# Ticker: BSLI3.SA - Shape (5615, 15)
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5615 entries, 0 to 5614
# Data columns (total 15 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   s_open_time              5615 non-null   object
#  1   open_time                5615 non-null   int64
#  2   ticker                   5615 non-null   object
#  3   open                     5615 non-null   float64
#  4   high                     5615 non-null   float64
#  5   low                      5615 non-null   float64
#  6   close                    5615 non-null   float64
#  7   adj_close                5615 non-null   float64
#  8   volume                   5615 non-null   int64
#  9   type                     5615 non-null   object
#  10  ema_adj_close_200p       5416 non-null   float32
#  11  ema_adj_close_200p_diff  5416 non-null   float32
#  12  ema_close_200p           5416 non-null   float32
#  13  ema_close_200p_diff      5416 non-null   float32
#  14  rsi                      3685 non-null   float64
# dtypes: float32(4), float64(6), int64(2), object(3)
# memory usage: 570.4+ KB
# Ticker: TRAD3.SA - Shape (586, 15)
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 586 entries, 0 to 585
# Data columns (total 15 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   s_open_time              586 non-null    object
#  1   open_time                586 non-null    int64
#  2   ticker                   586 non-null    object
#  3   open                     586 non-null    float64
#  4   high                     586 non-null    float64
#  5   low                      586 non-null    float64
#  6   close                    586 non-null    float64
#  7   adj_close                586 non-null    float64
#  8   volume                   586 non-null    int64
#  9   type                     586 non-null    object
#  10  ema_adj_close_200p       387 non-null    float32
#  11  ema_adj_close_200p_diff  387 non-null    float32
#  12  ema_close_200p           387 non-null    float32
#  13  ema_close_200p_diff      387 non-null    float32
#  14  rsi                      572 non-null    float64
# dtypes: float32(4), float64(6), int64(2), object(3)
# memory usage: 59.6+ KB
# Ticker: LPSB3.SA - Shape (4204, 15)
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4204 entries, 0 to 4203
# Data columns (total 15 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   s_open_time              4204 non-null   object
#  1   open_time                4204 non-null   int64
#  2   ticker                   4204 non-null   object
#  3   open                     4204 non-null   float64
#  4   high                     4204 non-null   float64
#  5   low                      4204 non-null   float64
#  6   close                    4204 non-null   float64
#  7   adj_close                4204 non-null   float64
#  8   volume                   4204 non-null   int64
#  9   type                     4204 non-null   object
#  10  ema_adj_close_200p       4005 non-null   float32
#  11  ema_adj_close_200p_diff  4005 non-null   float32
#  12  ema_close_200p           4005 non-null   float32
#  13  ema_close_200p_diff      4005 non-null   float32
#  14  rsi                      4190 non-null   float64
# dtypes: float32(4), float64(6), int64(2), object(3)
# memory usage: 427.1+ KB
# Ticker: ALPA3.SA - Shape (6007, 15)
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6007 entries, 0 to 6006
# Data columns (total 15 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   s_open_time              6007 non-null   object
#  1   open_time                6007 non-null   int64
#  2   ticker                   6007 non-null   object
#  3   open                     6007 non-null   float64
#  4   high                     6007 non-null   float64
#  5   low                      6007 non-null   float64
#  6   close                    6007 non-null   float64
#  7   adj_close                6007 non-null   float64
#  8   volume                   6007 non-null   int64
#  9   type                     6007 non-null   object
#  10  ema_adj_close_200p       5808 non-null   float32
#  11  ema_adj_close_200p_diff  5808 non-null   float32
#  12  ema_close_200p           5808 non-null   float32
#  13  ema_close_200p_diff      5808 non-null   float32
#  14  rsi                      5993 non-null   float64
# dtypes: float32(4), float64(6), int64(2), object(3)
# memory usage: 610.2+ KB
# calc_ema_periods: Não foi encontrado registros no período informado: 200
# calc_ema_periods: Não foi encontrado registros no período informado: 200
# index 14 is out of bounds for axis 0 with size 1
# Ticker: SOLR11.SA - Shape (1, 14)
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1 entries, 0 to 0
# Data columns (total 14 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   s_open_time              1 non-null      object
#  1   open_time                1 non-null      int64
#  2   ticker                   1 non-null      object
#  3   open                     1 non-null      float64
#  4   high                     1 non-null      float64
#  5   low                      1 non-null      float64
#  6   close                    1 non-null      float64
#  7   adj_close                1 non-null      float64
#  8   volume                   1 non-null      int64
#  9   type                     1 non-null      object
#  10  ema_adj_close_200p       0 non-null      object
#  11  ema_adj_close_200p_diff  0 non-null      object
#  12  ema_close_200p           0 non-null      object
#  13  ema_close_200p_diff      0 non-null      object
# dtypes: float64(5), int64(2), object(7)
# memory usage: 244.0+ bytes
# Ticker: GAME11.SA - Shape (473, 15)
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 473 entries, 0 to 472
# Data columns (total 15 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   s_open_time              473 non-null    object
#  1   open_time                473 non-null    int64
#  2   ticker                   473 non-null    object
#  3   open                     473 non-null    float64
#  4   high                     473 non-null    float64
#  5   low                      473 non-null    float64
#  6   close                    473 non-null    float64
#  7   adj_close                473 non-null    float64
#  8   volume                   473 non-null    int64
#  9   type                     473 non-null    object
#  10  ema_adj_close_200p       274 non-null    float32
#  11  ema_adj_close_200p_diff  274 non-null    float32
#  12  ema_close_200p           274 non-null    float32
#  13  ema_close_200p_diff      274 non-null    float32
#  14  rsi                      459 non-null    float64
# dtypes: float32(4), float64(6), int64(2), object(3)
# memory usage: 48.2+ KB
# Ticker: EALT4.SA - Shape (5982, 15)
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5982 entries, 0 to 5981
# Data columns (total 15 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   s_open_time              5982 non-null   object
#  1   open_time                5982 non-null   int64
#  2   ticker                   5982 non-null   object
#  3   open                     5982 non-null   float64
#  4   high                     5982 non-null   float64
#  5   low                      5982 non-null   float64
#  6   close                    5982 non-null   float64
#  7   adj_close                5982 non-null   float64
#  8   volume                   5982 non-null   int64
#  9   type                     5982 non-null   object
#  10  ema_adj_close_200p       5783 non-null   float32
#  11  ema_adj_close_200p_diff  5783 non-null   float32
#  12  ema_close_200p           5783 non-null   float32
#  13  ema_close_200p_diff      5783 non-null   float32
#  14  rsi                      5030 non-null   float64
# dtypes: float32(4), float64(6), int64(2), object(3)
# memory usage: 607.7+ KB
# Ticker: POMO3.SA - Shape (6000, 15)
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6000 entries, 0 to 5999
# Data columns (total 15 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   s_open_time              6000 non-null   object
#  1   open_time                6000 non-null   int64
#  2   ticker                   6000 non-null   object
#  3   open                     6000 non-null   float64
#  4   high                     6000 non-null   float64
#  5   low                      6000 non-null   float64
#  6   close                    6000 non-null   float64
#  7   adj_close                6000 non-null   float64
#  8   volume                   6000 non-null   int64
#  9   type                     6000 non-null   object
#  10  ema_adj_close_200p       5801 non-null   float32
#  11  ema_adj_close_200p_diff  5801 non-null   float32
#  12  ema_close_200p           5801 non-null   float32
#  13  ema_close_200p_diff      5801 non-null   float32
#  14  rsi                      5971 non-null   float64
# dtypes: float32(4), float64(6), int64(2), object(3)
# memory usage: 609.5+ KB
# /home/marcelo/des/xpe_projeto_aplicado/src/utils.py:127: RuntimeWarning: Mean of empty slice.
#   a[n] = x[1: n + 1].mean()
# /home/marcelo/des/xpe_projeto_aplicado/.env/lib64/python3.11/site-packages/numpy/core/_methods.py:129: RuntimeWarning: invalid value encountered in scalar divide
#   ret = ret.dtype.type(ret / rcount)
# Ticker: SLED3.SA - Shape (6006, 15)
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6006 entries, 0 to 6005
# Data columns (total 15 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   s_open_time              6006 non-null   object
#  1   open_time                6006 non-null   int64
#  2   ticker                   6006 non-null   object
#  3   open                     6006 non-null   float64
#  4   high                     6006 non-null   float64
#  5   low                      6006 non-null   float64
#  6   close                    6006 non-null   float64
#  7   adj_close                6006 non-null   float64
#  8   volume                   6006 non-null   int64
#  9   type                     6006 non-null   object
#  10  ema_adj_close_200p       5807 non-null   float32
#  11  ema_adj_close_200p_diff  5807 non-null   float32
#  12  ema_close_200p           5807 non-null   float32
#  13  ema_close_200p_diff      5807 non-null   float32
#  14  rsi                      5992 non-null   float64
# dtypes: float32(4), float64(6), int64(2), object(3)
# memory usage: 610.1+ KB
# Ticker: PLAS3.SA - Shape (6005, 15)
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6005 entries, 0 to 6004
# Data columns (total 15 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   s_open_time              6005 non-null   object
#  1   open_time                6005 non-null   int64
#  2   ticker                   6005 non-null   object
#  3   open                     6005 non-null   float64
#  4   high                     6005 non-null   float64
#  5   low                      6005 non-null   float64
#  6   close                    6005 non-null   float64
#  7   adj_close                6005 non-null   float64
#  8   volume                   6005 non-null   int64
#  9   type                     6005 non-null   object
#  10  ema_adj_close_200p       5806 non-null   float32
#  11  ema_adj_close_200p_diff  5806 non-null   float32
#  12  ema_close_200p           5806 non-null   float32
#  13  ema_close_200p_diff      5806 non-null   float32
#  14  rsi                      5991 non-null   float64
# dtypes: float32(4), float64(6), int64(2), object(3)
# memory usage: 610.0+ KB
# Ticker: VALE3.SA - Shape (6007, 15)
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6007 entries, 0 to 6006
# Data columns (total 15 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   s_open_time              6007 non-null   object
#  1   open_time                6007 non-null   int64
#  2   ticker                   6007 non-null   object
#  3   open                     6007 non-null   float64
#  4   high                     6007 non-null   float64
#  5   low                      6007 non-null   float64
#  6   close                    6007 non-null   float64
#  7   adj_close                6007 non-null   float64
#  8   volume                   6007 non-null   int64
#  9   type                     6007 non-null   object
#  10  ema_adj_close_200p       5808 non-null   float32
#  11  ema_adj_close_200p_diff  5808 non-null   float32
#  12  ema_close_200p           5808 non-null   float32
#  13  ema_close_200p_diff      5808 non-null   float32
#  14  rsi                      5993 non-null   float64
# dtypes: float32(4), float64(6), int64(2), object(3)
# memory usage: 610.2+ KB
# Ticker: VGIP11.SA - Shape (920, 15)
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 920 entries, 0 to 919
# Data columns (total 15 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   s_open_time              920 non-null    object
#  1   open_time                920 non-null    int64
#  2   ticker                   920 non-null    object
#  3   open                     920 non-null    float64
#  4   high                     920 non-null    float64
#  5   low                      920 non-null    float64
#  6   close                    920 non-null    float64
#  7   adj_close                920 non-null    float64
#  8   volume                   920 non-null    int64
#  9   type                     920 non-null    object
#  10  ema_adj_close_200p       721 non-null    float32
#  11  ema_adj_close_200p_diff  721 non-null    float32
#  12  ema_close_200p           721 non-null    float32
#  13  ema_close_200p_diff      721 non-null    float32
#  14  rsi                      906 non-null    float64
# dtypes: float32(4), float64(6), int64(2), object(3)
# memory usage: 93.6+ KB
# Ticker: LAND3.SA - Shape (577, 15)
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 577 entries, 0 to 576
# Data columns (total 15 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   s_open_time              577 non-null    object
#  1   open_time                577 non-null    int64
#  2   ticker                   577 non-null    object
#  3   open                     577 non-null    float64
#  4   high                     577 non-null    float64
#  5   low                      577 non-null    float64
#  6   close                    577 non-null    float64
#  7   adj_close                577 non-null    float64
#  8   volume                   577 non-null    int64
#  9   type                     577 non-null    object
#  10  ema_adj_close_200p       378 non-null    float32
#  11  ema_adj_close_200p_diff  378 non-null    float32
#  12  ema_close_200p           378 non-null    float32
#  13  ema_close_200p_diff      378 non-null    float32
#  14  rsi                      563 non-null    float64
# dtypes: float32(4), float64(6), int64(2), object(3)
# memory usage: 58.7+ KB
# Ticker: BIOM3.SA - Shape (6001, 15)
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6001 entries, 0 to 6000
# Data columns (total 15 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   s_open_time              6001 non-null   object
#  1   open_time                6001 non-null   int64
#  2   ticker                   6001 non-null   object
#  3   open                     6001 non-null   float64
#  4   high                     6001 non-null   float64
#  5   low                      6001 non-null   float64
#  6   close                    6001 non-null   float64
#  7   adj_close                6001 non-null   float64
#  8   volume                   6001 non-null   int64
#  9   type                     6001 non-null   object
#  10  ema_adj_close_200p       5802 non-null   float32
#  11  ema_adj_close_200p_diff  5802 non-null   float32
#  12  ema_close_200p           5802 non-null   float32
#  13  ema_close_200p_diff      5802 non-null   float32
#  14  rsi                      5987 non-null   float64
# dtypes: float32(4), float64(6), int64(2), object(3)
# memory usage: 609.6+ KB
# Ticker: BMEB3.SA - Shape (5866, 15)
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5866 entries, 0 to 5865
# Data columns (total 15 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   s_open_time              5866 non-null   object
#  1   open_time                5866 non-null   int64
#  2   ticker                   5866 non-null   object
#  3   open                     5866 non-null   float64
#  4   high                     5866 non-null   float64
#  5   low                      5866 non-null   float64
#  6   close                    5866 non-null   float64
#  7   adj_close                5866 non-null   float64
#  8   volume                   5866 non-null   int64
#  9   type                     5866 non-null   object
#  10  ema_adj_close_200p       5667 non-null   float32
#  11  ema_adj_close_200p_diff  5667 non-null   float32
#  12  ema_close_200p           5667 non-null   float32
#  13  ema_close_200p_diff      5667 non-null   float32
#  14  rsi                      5852 non-null   float64
# dtypes: float32(4), float64(6), int64(2), object(3)
# memory usage: 595.9+ KB
# calc_ema_periods: Não foi encontrado registros no período informado: 200
# calc_ema_periods: Não foi encontrado registros no período informado: 200
# Ticker: FGAA11.SA - Shape (198, 15)
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 198 entries, 0 to 197
# Data columns (total 15 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   s_open_time              198 non-null    object
#  1   open_time                198 non-null    int64
#  2   ticker                   198 non-null    object
#  3   open                     198 non-null    float64
#  4   high                     198 non-null    float64
#  5   low                      198 non-null    float64
#  6   close                    198 non-null    float64
#  7   adj_close                198 non-null    float64
#  8   volume                   198 non-null    int64
#  9   type                     198 non-null    object
#  10  ema_adj_close_200p       0 non-null      object
#  11  ema_adj_close_200p_diff  0 non-null      object
#  12  ema_close_200p           0 non-null      object
#  13  ema_close_200p_diff      0 non-null      object
#  14  rsi                      184 non-null    float64
# dtypes: float64(6), int64(2), object(7)
# memory usage: 23.3+ KB
# Ticker: BTCR11.SA - Shape (1218, 15)
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1218 entries, 0 to 1217
# Data columns (total 15 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   s_open_time              1218 non-null   object
#  1   open_time                1218 non-null   int64
#  2   ticker                   1218 non-null   object
#  3   open                     1218 non-null   float64
#  4   high                     1218 non-null   float64
#  5   low                      1218 non-null   float64
#  6   close                    1218 non-null   float64
#  7   adj_close                1218 non-null   float64
#  8   volume                   1218 non-null   int64
#  9   type                     1218 non-null   object
#  10  ema_adj_close_200p       1019 non-null   float32
#  11  ema_adj_close_200p_diff  1019 non-null   float32
#  12  ema_close_200p           1019 non-null   float32
#  13  ema_close_200p_diff      1019 non-null   float32
#  14  rsi                      1187 non-null   float64
# dtypes: float32(4), float64(6), int64(2), object(3)
# memory usage: 123.8+ KB
# Ticker: BPFF11.SA - Shape (2319, 15)
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2319 entries, 0 to 2318
# Data columns (total 15 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   s_open_time              2319 non-null   object
#  1   open_time                2319 non-null   int64
#  2   ticker                   2319 non-null   object
#  3   open                     2319 non-null   float64
#  4   high                     2319 non-null   float64
#  5   low                      2319 non-null   float64
#  6   close                    2319 non-null   float64
#  7   adj_close                2319 non-null   float64
#  8   volume                   2319 non-null   int64
#  9   type                     2319 non-null   object
#  10  ema_adj_close_200p       2120 non-null   float32
#  11  ema_adj_close_200p_diff  2120 non-null   float32
#  12  ema_close_200p           2120 non-null   float32
#  13  ema_close_200p_diff      2120 non-null   float32
#  14  rsi                      2305 non-null   float64
# dtypes: float32(4), float64(6), int64(2), object(3)
# memory usage: 235.7+ KB
# Ticker: USIM3.SA - Shape (6006, 15)
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6006 entries, 0 to 6005
# Data columns (total 15 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   s_open_time              6006 non-null   object
#  1   open_time                6006 non-null   int64
#  2   ticker                   6006 non-null   object
#  3   open                     6006 non-null   float64
#  4   high                     6006 non-null   float64
#  5   low                      6006 non-null   float64
#  6   close                    6006 non-null   float64
#  7   adj_close                6006 non-null   float64
#  8   volume                   6006 non-null   int64
#  9   type                     6006 non-null   object
#  10  ema_adj_close_200p       5807 non-null   float32
#  11  ema_adj_close_200p_diff  5807 non-null   float32
#  12  ema_close_200p           5807 non-null   float32
#  13  ema_close_200p_diff      5807 non-null   float32
#  14  rsi                      5992 non-null   float64
# dtypes: float32(4), float64(6), int64(2), object(3)
# memory usage: 610.1+ KB
# Ticker: TRXF11.SA - Shape (941, 15)
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 941 entries, 0 to 940
# Data columns (total 15 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   s_open_time              941 non-null    object
#  1   open_time                941 non-null    int64
#  2   ticker                   941 non-null    object
#  3   open                     941 non-null    float64
#  4   high                     941 non-null    float64
#  5   low                      941 non-null    float64
#  6   close                    941 non-null    float64
#  7   adj_close                941 non-null    float64
#  8   volume                   941 non-null    int64
#  9   type                     941 non-null    object
#  10  ema_adj_close_200p       742 non-null    float32
#  11  ema_adj_close_200p_diff  742 non-null    float32
#  12  ema_close_200p           742 non-null    float32
#  13  ema_close_200p_diff      742 non-null    float32
#  14  rsi                      927 non-null    float64
# dtypes: float32(4), float64(6), int64(2), object(3)
# memory usage: 95.7+ KB
# Ticker: JPPA11.SA - Shape (941, 15)
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 941 entries, 0 to 940
# Data columns (total 15 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   s_open_time              941 non-null    object
#  1   open_time                941 non-null    int64
#  2   ticker                   941 non-null    object
#  3   open                     941 non-null    float64
#  4   high                     941 non-null    float64
#  5   low                      941 non-null    float64
#  6   close                    941 non-null    float64
#  7   adj_close                941 non-null    float64
#  8   volume                   941 non-null    int64
#  9   type                     941 non-null    object
#  10  ema_adj_close_200p       742 non-null    float32
#  11  ema_adj_close_200p_diff  742 non-null    float32
#  12  ema_close_200p           742 non-null    float32
#  13  ema_close_200p_diff      742 non-null    float32
#  14  rsi                      927 non-null    float64
# dtypes: float32(4), float64(6), int64(2), object(3)
# memory usage: 95.7+ KB
# Ticker: LREN3.SA - Shape (6006, 15)
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6006 entries, 0 to 6005
# Data columns (total 15 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   s_open_time              6006 non-null   object
#  1   open_time                6006 non-null   int64
#  2   ticker                   6006 non-null   object
#  3   open                     6006 non-null   float64
#  4   high                     6006 non-null   float64
#  5   low                      6006 non-null   float64
#  6   close                    6006 non-null   float64
#  7   adj_close                6006 non-null   float64
#  8   volume                   6006 non-null   int64
#  9   type                     6006 non-null   object
#  10  ema_adj_close_200p       5807 non-null   float32
#  11  ema_adj_close_200p_diff  5807 non-null   float32
#  12  ema_close_200p           5807 non-null   float32
#  13  ema_close_200p_diff      5807 non-null   float32
#  14  rsi                      5984 non-null   float64
# dtypes: float32(4), float64(6), int64(2), object(3)
# memory usage: 610.1+ KB
# Ticker: VIFI11.SA - Shape (865, 15)
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 865 entries, 0 to 864
# Data columns (total 15 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   s_open_time              865 non-null    object
#  1   open_time                865 non-null    int64
#  2   ticker                   865 non-null    object
#  3   open                     865 non-null    float64
#  4   high                     865 non-null    float64
#  5   low                      865 non-null    float64
#  6   close                    865 non-null    float64
#  7   adj_close                865 non-null    float64
#  8   volume                   865 non-null    int64
#  9   type                     865 non-null    object
#  10  ema_adj_close_200p       666 non-null    float32
#  11  ema_adj_close_200p_diff  666 non-null    float32
#  12  ema_close_200p           666 non-null    float32
#  13  ema_close_200p_diff      666 non-null    float32
#  14  rsi                      851 non-null    float64
# dtypes: float32(4), float64(6), int64(2), object(3)
# memory usage: 88.0+ KB
# Ticker: BBSE3.SA - Shape (2634, 15)
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2634 entries, 0 to 2633
# Data columns (total 15 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   s_open_time              2634 non-null   object
#  1   open_time                2634 non-null   int64
#  2   ticker                   2634 non-null   object
#  3   open                     2634 non-null   float64
#  4   high                     2634 non-null   float64
#  5   low                      2634 non-null   float64
#  6   close                    2634 non-null   float64
#  7   adj_close                2634 non-null   float64
#  8   volume                   2634 non-null   int64
#  9   type                     2634 non-null   object
#  10  ema_adj_close_200p       2435 non-null   float32
#  11  ema_adj_close_200p_diff  2435 non-null   float32
#  12  ema_close_200p           2435 non-null   float32
#  13  ema_close_200p_diff      2435 non-null   float32
#  14  rsi                      2620 non-null   float64
# dtypes: float32(4), float64(6), int64(2), object(3)
# memory usage: 267.6+ KB
# Ticker: PRNR3.SA - Shape (942, 15)
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 942 entries, 0 to 941
# Data columns (total 15 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   s_open_time              942 non-null    object
#  1   open_time                942 non-null    int64
#  2   ticker                   942 non-null    object
#  3   open                     942 non-null    float64
#  4   high                     942 non-null    float64
#  5   low                      942 non-null    float64
#  6   close                    942 non-null    float64
#  7   adj_close                942 non-null    float64
#  8   volume                   942 non-null    int64
#  9   type                     942 non-null    object
#  10  ema_adj_close_200p       743 non-null    float32
#  11  ema_adj_close_200p_diff  743 non-null    float32
#  12  ema_close_200p           743 non-null    float32
#  13  ema_close_200p_diff      743 non-null    float32
#  14  rsi                      928 non-null    float64
# dtypes: float32(4), float64(6), int64(2), object(3)
# memory usage: 95.8+ KB
# Ticker: ANIM3.SA - Shape (2507, 15)
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2507 entries, 0 to 2506
# Data columns (total 15 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   s_open_time              2507 non-null   object
#  1   open_time                2507 non-null   int64
#  2   ticker                   2507 non-null   object
#  3   open                     2507 non-null   float64
#  4   high                     2507 non-null   float64
#  5   low                      2507 non-null   float64
#  6   close                    2507 non-null   float64
#  7   adj_close                2507 non-null   float64
#  8   volume                   2507 non-null   int64
#  9   type                     2507 non-null   object
#  10  ema_adj_close_200p       2308 non-null   float32
#  11  ema_adj_close_200p_diff  2308 non-null   float32
#  12  ema_close_200p           2308 non-null   float32
#  13  ema_close_200p_diff      2308 non-null   float32
#  14  rsi                      2493 non-null   float64
# dtypes: float32(4), float64(6), int64(2), object(3)
# memory usage: 254.7+ KB
# Ticker: MEAL3.SA - Shape (3160, 15)
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3160 entries, 0 to 3159
# Data columns (total 15 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   s_open_time              3160 non-null   object
#  1   open_time                3160 non-null   int64
#  2   ticker                   3160 non-null   object
#  3   open                     3160 non-null   float64
#  4   high                     3160 non-null   float64
#  5   low                      3160 non-null   float64
#  6   close                    3160 non-null   float64
#  7   adj_close                3160 non-null   float64
#  8   volume                   3160 non-null   int64
#  9   type                     3160 non-null   object
#  10  ema_adj_close_200p       2961 non-null   float32
#  11  ema_adj_close_200p_diff  2961 non-null   float32
#  12  ema_close_200p           2961 non-null   float32
#  13  ema_close_200p_diff      2961 non-null   float32
#  14  rsi                      3146 non-null   float64
# dtypes: float32(4), float64(6), int64(2), object(3)
# memory usage: 321.1+ KB
# Ticker: BRGE12.SA - Shape (6004, 15)
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6004 entries, 0 to 6003
# Data columns (total 15 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   s_open_time              6004 non-null   object
#  1   open_time                6004 non-null   int64
#  2   ticker                   6004 non-null   object
#  3   open                     6004 non-null   float64
#  4   high                     6004 non-null   float64
#  5   low                      6004 non-null   float64
#  6   close                    6004 non-null   float64
#  7   adj_close                6004 non-null   float64
#  8   volume                   6004 non-null   int64
#  9   type                     6004 non-null   object
#  10  ema_adj_close_200p       5805 non-null   float32
#  11  ema_adj_close_200p_diff  5805 non-null   float32
#  12  ema_close_200p           5805 non-null   float32
#  13  ema_close_200p_diff      5805 non-null   float32
#  14  rsi                      5990 non-null   float64
# dtypes: float32(4), float64(6), int64(2), object(3)
# memory usage: 609.9+ KB
# Ticker: MATV11.SA - Shape (360, 15)
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 360 entries, 0 to 359
# Data columns (total 15 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   s_open_time              360 non-null    object
#  1   open_time                360 non-null    int64
#  2   ticker                   360 non-null    object
#  3   open                     360 non-null    float64
#  4   high                     360 non-null    float64
#  5   low                      360 non-null    float64
#  6   close                    360 non-null    float64
#  7   adj_close                360 non-null    float64
#  8   volume                   360 non-null    int64
#  9   type                     360 non-null    object
#  10  ema_adj_close_200p       161 non-null    float32
#  11  ema_adj_close_200p_diff  161 non-null    float32
#  12  ema_close_200p           161 non-null    float32
#  13  ema_close_200p_diff      161 non-null    float32
#  14  rsi                      346 non-null    float64
# dtypes: float32(4), float64(6), int64(2), object(3)
# memory usage: 36.7+ KB
# Ticker: JOPA4.SA - Shape (5189, 15)
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5189 entries, 0 to 5188
# Data columns (total 15 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   s_open_time              5189 non-null   object
#  1   open_time                5189 non-null   int64
#  2   ticker                   5189 non-null   object
#  3   open                     5189 non-null   float64
#  4   high                     5189 non-null   float64
#  5   low                      5189 non-null   float64
#  6   close                    5189 non-null   float64
#  7   adj_close                5189 non-null   float64
#  8   volume                   5189 non-null   int64
#  9   type                     5189 non-null   object
#  10  ema_adj_close_200p       4990 non-null   float32
#  11  ema_adj_close_200p_diff  4990 non-null   float32
#  12  ema_close_200p           4990 non-null   float32
#  13  ema_close_200p_diff      4990 non-null   float32
#  14  rsi                      4836 non-null   float64
# dtypes: float32(4), float64(6), int64(2), object(3)
# memory usage: 527.1+ KB
# Ticker: MYPK3.SA - Shape (4891, 15)
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4891 entries, 0 to 4890
# Data columns (total 15 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   s_open_time              4891 non-null   object
#  1   open_time                4891 non-null   int64
#  2   ticker                   4891 non-null   object
#  3   open                     4891 non-null   float64
#  4   high                     4891 non-null   float64
#  5   low                      4891 non-null   float64
#  6   close                    4891 non-null   float64
#  7   adj_close                4891 non-null   float64
#  8   volume                   4891 non-null   int64
#  9   type                     4891 non-null   object
#  10  ema_adj_close_200p       4692 non-null   float32
#  11  ema_adj_close_200p_diff  4692 non-null   float32
#  12  ema_close_200p           4692 non-null   float32
#  13  ema_close_200p_diff      4692 non-null   float32
#  14  rsi                      4877 non-null   float64
# dtypes: float32(4), float64(6), int64(2), object(3)
# memory usage: 496.9+ KB
# calc_ema_periods: Não foi encontrado registros no período informado: 200
# calc_ema_periods: Não foi encontrado registros no período informado: 200
# Ticker: ARXD11.SA - Shape (148, 15)
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 148 entries, 0 to 147
# Data columns (total 15 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   s_open_time              148 non-null    object
#  1   open_time                148 non-null    int64
#  2   ticker                   148 non-null    object
#  3   open                     148 non-null    float64
#  4   high                     148 non-null    float64
#  5   low                      148 non-null    float64
#  6   close                    148 non-null    float64
#  7   adj_close                148 non-null    float64
#  8   volume                   148 non-null    int64
#  9   type                     148 non-null    object
#  10  ema_adj_close_200p       0 non-null      object
#  11  ema_adj_close_200p_diff  0 non-null      object
#  12  ema_close_200p           0 non-null      object
#  13  ema_close_200p_diff      0 non-null      object
#  14  rsi                      126 non-null    float64
# dtypes: float64(6), int64(2), object(7)
# memory usage: 17.5+ KB
# Ticker: CTNM3.SA - Shape (6005, 15)
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6005 entries, 0 to 6004
# Data columns (total 15 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   s_open_time              6005 non-null   object
#  1   open_time                6005 non-null   int64
#  2   ticker                   6005 non-null   object
#  3   open                     6005 non-null   float64
#  4   high                     6005 non-null   float64
#  5   low                      6005 non-null   float64
#  6   close                    6005 non-null   float64
#  7   adj_close                6005 non-null   float64
#  8   volume                   6005 non-null   int64
#  9   type                     6005 non-null   object
#  10  ema_adj_close_200p       5806 non-null   float32
#  11  ema_adj_close_200p_diff  5806 non-null   float32
#  12  ema_close_200p           5806 non-null   float32
#  13  ema_close_200p_diff      5806 non-null   float32
#  14  rsi                      5991 non-null   float64
# dtypes: float32(4), float64(6), int64(2), object(3)
# memory usage: 610.0+ KB
# calc_ema_periods: Não foi encontrado registros no período informado: 200
# calc_ema_periods: Não foi encontrado registros no período informado: 200
# Ticker: IGTI4.SA - Shape (177, 15)
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 177 entries, 0 to 176
# Data columns (total 15 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   s_open_time              177 non-null    object
#  1   open_time                177 non-null    int64
#  2   ticker                   177 non-null    object
#  3   open                     177 non-null    float64
#  4   high                     177 non-null    float64
#  5   low                      177 non-null    float64
#  6   close                    177 non-null    float64
#  7   adj_close                177 non-null    float64
#  8   volume                   177 non-null    int64
#  9   type                     177 non-null    object
#  10  ema_adj_close_200p       0 non-null      object
#  11  ema_adj_close_200p_diff  0 non-null      object
#  12  ema_close_200p           0 non-null      object
#  13  ema_close_200p_diff      0 non-null      object
#  14  rsi                      163 non-null    float64
# dtypes: float64(6), int64(2), object(7)
# memory usage: 20.9+ KB
# Ticker: RNEW3.SA - Shape (2548, 15)
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2548 entries, 0 to 2547
# Data columns (total 15 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   s_open_time              2548 non-null   object
#  1   open_time                2548 non-null   int64
#  2   ticker                   2548 non-null   object
#  3   open                     2548 non-null   float64
#  4   high                     2548 non-null   float64
#  5   low                      2548 non-null   float64
#  6   close                    2548 non-null   float64
#  7   adj_close                2548 non-null   float64
#  8   volume                   2548 non-null   int64
#  9   type                     2548 non-null   object
#  10  ema_adj_close_200p       2349 non-null   float32
#  11  ema_adj_close_200p_diff  2349 non-null   float32
#  12  ema_close_200p           2349 non-null   float32
#  13  ema_close_200p_diff      2349 non-null   float32
#  14  rsi                      2534 non-null   float64
# dtypes: float32(4), float64(6), int64(2), object(3)
# memory usage: 258.9+ KB
# Ticker: MAPT3.SA - Shape (5859, 15)
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5859 entries, 0 to 5858
# Data columns (total 15 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   s_open_time              5859 non-null   object
#  1   open_time                5859 non-null   int64
#  2   ticker                   5859 non-null   object
#  3   open                     5859 non-null   float64
#  4   high                     5859 non-null   float64
#  5   low                      5859 non-null   float64
#  6   close                    5859 non-null   float64
#  7   adj_close                5859 non-null   float64
#  8   volume                   5859 non-null   int64
#  9   type                     5859 non-null   object
#  10  ema_adj_close_200p       5660 non-null   float32
#  11  ema_adj_close_200p_diff  5660 non-null   float32
#  12  ema_close_200p           5660 non-null   float32
#  13  ema_close_200p_diff      5660 non-null   float32
#  14  rsi                      5845 non-null   float64
# dtypes: float32(4), float64(6), int64(2), object(3)
# memory usage: 595.2+ KB
# Ticker: MWET3.SA - Shape (4759, 15)
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4759 entries, 0 to 4758
# Data columns (total 15 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   s_open_time              4759 non-null   object
#  1   open_time                4759 non-null   int64
#  2   ticker                   4759 non-null   object
#  3   open                     4759 non-null   float64
#  4   high                     4759 non-null   float64
#  5   low                      4759 non-null   float64
#  6   close                    4759 non-null   float64
#  7   adj_close                4759 non-null   float64
#  8   volume                   4759 non-null   int64
#  9   type                     4759 non-null   object
#  10  ema_adj_close_200p       4560 non-null   float32
#  11  ema_adj_close_200p_diff  4560 non-null   float32
#  12  ema_close_200p           4560 non-null   float32
#  13  ema_close_200p_diff      4560 non-null   float32
#  14  rsi                      4745 non-null   float64
# dtypes: float32(4), float64(6), int64(2), object(3)
# memory usage: 483.5+ KB
# Ticker: IBFF11.SA - Shape (939, 15)
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 939 entries, 0 to 938
# Data columns (total 15 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   s_open_time              939 non-null    object
#  1   open_time                939 non-null    int64
#  2   ticker                   939 non-null    object
#  3   open                     939 non-null    float64
#  4   high                     939 non-null    float64
#  5   low                      939 non-null    float64
#  6   close                    939 non-null    float64
#  7   adj_close                939 non-null    float64
#  8   volume                   939 non-null    int64
#  9   type                     939 non-null    object
#  10  ema_adj_close_200p       740 non-null    float32
#  11  ema_adj_close_200p_diff  740 non-null    float32
#  12  ema_close_200p           740 non-null    float32
#  13  ema_close_200p_diff      740 non-null    float32
#  14  rsi                      925 non-null    float64
# dtypes: float32(4), float64(6), int64(2), object(3)
# memory usage: 95.5+ KB
# Ticker: CEED3.SA - Shape (3369, 15)
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3369 entries, 0 to 3368
# Data columns (total 15 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   s_open_time              3369 non-null   object
#  1   open_time                3369 non-null   int64
#  2   ticker                   3369 non-null   object
#  3   open                     3369 non-null   float64
#  4   high                     3369 non-null   float64
#  5   low                      3369 non-null   float64
# ...
#  2   ticker                   4734 non-null   object
#  3   open                     4734 non-null   float64
#  4   high                     4734 non-null   float64
#  5   low                      4734 non-null   float64
#  6   close                    4734 non-null   float64
#  7   adj_close                4734 non-null   float64
#  8   volume                   4734 non-null   int64
#  9   type                     4734 non-null   object
#  10  ema_adj_close_200p       4535 non-null   float32
#  11  ema_adj_close_200p_diff  4535 non-null   float32
#  12  ema_close_200p           4535 non-null   float32
#  13  ema_close_200p_diff      4535 non-null   float32
#  14  rsi                      4720 non-null   float64
# dtypes: float32(4), float64(6), int64(2), object(3)
# memory usage: 480.9+ KB
# Ticker: SHOP11.SA - Shape (229, 15)
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 229 entries, 0 to 228
# Data columns (total 15 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   s_open_time              229 non-null    object
#  1   open_time                229 non-null    int64
#  2   ticker                   229 non-null    object
#  3   open                     229 non-null    float64
#  4   high                     229 non-null    float64
#  5   low                      229 non-null    float64
#  6   close                    229 non-null    float64
#  7   adj_close                229 non-null    float64
#  8   volume                   229 non-null    int64
#  9   type                     229 non-null    object
#  10  ema_adj_close_200p       30 non-null     float32
#  11  ema_adj_close_200p_diff  30 non-null     float32
#  12  ema_close_200p           30 non-null     float32
#  13  ema_close_200p_diff      30 non-null     float32
#  14  rsi                      215 non-null    float64
# dtypes: float32(4), float64(6), int64(2), object(3)
# memory usage: 23.4+ KB
# Ticker: HBRH11.SA - Shape (869, 15)
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 869 entries, 0 to 868
# Data columns (total 15 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   s_open_time              869 non-null    object
#  1   open_time                869 non-null    int64
#  2   ticker                   869 non-null    object
#  3   open                     869 non-null    float64
#  4   high                     869 non-null    float64
#  5   low                      869 non-null    float64
#  6   close                    869 non-null    float64
#  7   adj_close                869 non-null    float64
#  8   volume                   869 non-null    int64
#  9   type                     869 non-null    object
#  10  ema_adj_close_200p       670 non-null    float32
#  11  ema_adj_close_200p_diff  670 non-null    float32
#  12  ema_close_200p           670 non-null    float32
#  13  ema_close_200p_diff      670 non-null    float32
#  14  rsi                      855 non-null    float64
# dtypes: float32(4), float64(6), int64(2), object(3)
# memory usage: 88.4+ KB
# Ticker: LAVV3.SA - Shape (805, 15)
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 805 entries, 0 to 804
# Data columns (total 15 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   s_open_time              805 non-null    object
#  1   open_time                805 non-null    int64
#  2   ticker                   805 non-null    object
#  3   open                     805 non-null    float64
#  4   high                     805 non-null    float64
#  5   low                      805 non-null    float64
#  6   close                    805 non-null    float64
#  7   adj_close                805 non-null    float64
#  8   volume                   805 non-null    int64
#  9   type                     805 non-null    object
#  10  ema_adj_close_200p       606 non-null    float32
#  11  ema_adj_close_200p_diff  606 non-null    float32
#  12  ema_close_200p           606 non-null    float32
#  13  ema_close_200p_diff      606 non-null    float32
#  14  rsi                      791 non-null    float64
# dtypes: float32(4), float64(6), int64(2), object(3)
# memory usage: 81.9+ KB
# calc_ema_periods: Não foi encontrado registros no período informado: 200
# calc_ema_periods: Não foi encontrado registros no período informado: 200
# index 14 is out of bounds for axis 0 with size 1
# Ticker: TJKB11.SA - Shape (1, 14)
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1 entries, 0 to 0
# Data columns (total 14 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   s_open_time              1 non-null      object
#  1   open_time                1 non-null      int64
#  2   ticker                   1 non-null      object
#  3   open                     1 non-null      float64
#  4   high                     1 non-null      float64
#  5   low                      1 non-null      float64
#  6   close                    1 non-null      float64
#  7   adj_close                1 non-null      float64
#  8   volume                   1 non-null      int64
#  9   type                     1 non-null      object
#  10  ema_adj_close_200p       0 non-null      object
#  11  ema_adj_close_200p_diff  0 non-null      object
#  12  ema_close_200p           0 non-null      object
#  13  ema_close_200p_diff      0 non-null      object
# dtypes: float64(5), int64(2), object(7)
# memory usage: 244.0+ bytes
# Ticker: PRSV11.SA - Shape (2318, 15)
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2318 entries, 0 to 2317
# Data columns (total 15 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   s_open_time              2318 non-null   object
#  1   open_time                2318 non-null   int64
#  2   ticker                   2318 non-null   object
#  3   open                     2318 non-null   float64
#  4   high                     2318 non-null   float64
#  5   low                      2318 non-null   float64
#  6   close                    2318 non-null   float64
#  7   adj_close                2318 non-null   float64
#  8   volume                   2318 non-null   int64
#  9   type                     2318 non-null   object
#  10  ema_adj_close_200p       2119 non-null   float32
#  11  ema_adj_close_200p_diff  2119 non-null   float32
#  12  ema_close_200p           2119 non-null   float32
#  13  ema_close_200p_diff      2119 non-null   float32
#  14  rsi                      2304 non-null   float64
# dtypes: float32(4), float64(6), int64(2), object(3)
# memory usage: 235.6+ KB
# Ticker: VAMO3.SA - Shape (706, 15)
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 706 entries, 0 to 705
# Data columns (total 15 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   s_open_time              706 non-null    object
#  1   open_time                706 non-null    int64
#  2   ticker                   706 non-null    object
#  3   open                     706 non-null    float64
#  4   high                     706 non-null    float64
#  5   low                      706 non-null    float64
#  6   close                    706 non-null    float64
#  7   adj_close                706 non-null    float64
#  8   volume                   706 non-null    int64
#  9   type                     706 non-null    object
#  10  ema_adj_close_200p       507 non-null    float32
#  11  ema_adj_close_200p_diff  507 non-null    float32
#  12  ema_close_200p           507 non-null    float32
#  13  ema_close_200p_diff      507 non-null    float32
#  14  rsi                      692 non-null    float64
# dtypes: float32(4), float64(6), int64(2), object(3)
# memory usage: 71.8+ KB
# Ticker: CEBR3.SA - Shape (6006, 15)
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6006 entries, 0 to 6005
# Data columns (total 15 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   s_open_time              6006 non-null   object
#  1   open_time                6006 non-null   int64
#  2   ticker                   6006 non-null   object
#  3   open                     6006 non-null   float64
#  4   high                     6006 non-null   float64
#  5   low                      6006 non-null   float64
#  6   close                    6006 non-null   float64
#  7   adj_close                6006 non-null   float64
#  8   volume                   6006 non-null   int64
#  9   type                     6006 non-null   object
#  10  ema_adj_close_200p       5807 non-null   float32
#  11  ema_adj_close_200p_diff  5807 non-null   float32
#  12  ema_close_200p           5807 non-null   float32
#  13  ema_close_200p_diff      5807 non-null   float32
#  14  rsi                      5959 non-null   float64
# dtypes: float32(4), float64(6), int64(2), object(3)
# memory usage: 610.1+ KB
# Ticker: BCIA11.SA - Shape (1528, 15)
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1528 entries, 0 to 1527
# Data columns (total 15 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   s_open_time              1528 non-null   object
#  1   open_time                1528 non-null   int64
#  2   ticker                   1528 non-null   object
#  3   open                     1528 non-null   float64
#  4   high                     1528 non-null   float64
#  5   low                      1528 non-null   float64
#  6   close                    1528 non-null   float64
#  7   adj_close                1528 non-null   float64
#  8   volume                   1528 non-null   int64
#  9   type                     1528 non-null   object
#  10  ema_adj_close_200p       1329 non-null   float32
#  11  ema_adj_close_200p_diff  1329 non-null   float32
#  12  ema_close_200p           1329 non-null   float32
#  13  ema_close_200p_diff      1329 non-null   float32
#  14  rsi                      1514 non-null   float64
# dtypes: float32(4), float64(6), int64(2), object(3)
# memory usage: 155.3+ KB
# Ticker: SGPS3.SA - Shape (4055, 15)
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4055 entries, 0 to 4054
# Data columns (total 15 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   s_open_time              4055 non-null   object
#  1   open_time                4055 non-null   int64
#  2   ticker                   4055 non-null   object
#  3   open                     4055 non-null   float64
#  4   high                     4055 non-null   float64
#  5   low                      4055 non-null   float64
#  6   close                    4055 non-null   float64
#  7   adj_close                4055 non-null   float64
#  8   volume                   4055 non-null   int64
#  9   type                     4055 non-null   object
#  10  ema_adj_close_200p       3856 non-null   float32
#  11  ema_adj_close_200p_diff  3856 non-null   float32
#  12  ema_close_200p           3856 non-null   float32
#  13  ema_close_200p_diff      3856 non-null   float32
#  14  rsi                      4041 non-null   float64
# dtypes: float32(4), float64(6), int64(2), object(3)
# memory usage: 412.0+ KB
# Ticker: HBRE3.SA - Shape (711, 15)
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 711 entries, 0 to 710
# Data columns (total 15 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   s_open_time              711 non-null    object
#  1   open_time                711 non-null    int64
#  2   ticker                   711 non-null    object
#  3   open                     711 non-null    float64
#  4   high                     711 non-null    float64
#  5   low                      711 non-null    float64
#  6   close                    711 non-null    float64
#  7   adj_close                711 non-null    float64
#  8   volume                   711 non-null    int64
#  9   type                     711 non-null    object
#  10  ema_adj_close_200p       512 non-null    float32
#  11  ema_adj_close_200p_diff  512 non-null    float32
#  12  ema_close_200p           512 non-null    float32
#  13  ema_close_200p_diff      512 non-null    float32
#  14  rsi                      697 non-null    float64
# dtypes: float32(4), float64(6), int64(2), object(3)
# memory usage: 72.3+ KB
# Ticker: OIAG11.SA - Shape (382, 15)
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 382 entries, 0 to 381
# Data columns (total 15 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   s_open_time              382 non-null    object
#  1   open_time                382 non-null    int64
#  2   ticker                   382 non-null    object
#  3   open                     382 non-null    float64
#  4   high                     382 non-null    float64
#  5   low                      382 non-null    float64
#  6   close                    382 non-null    float64
#  7   adj_close                382 non-null    float64
#  8   volume                   382 non-null    int64
#  9   type                     382 non-null    object
#  10  ema_adj_close_200p       183 non-null    float32
#  11  ema_adj_close_200p_diff  183 non-null    float32
#  12  ema_close_200p           183 non-null    float32
#  13  ema_close_200p_diff      183 non-null    float32
#  14  rsi                      368 non-null    float64
# dtypes: float32(4), float64(6), int64(2), object(3)
# memory usage: 38.9+ KB
# Ticker: QAMI11.SA - Shape (629, 15)
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 629 entries, 0 to 628
# Data columns (total 15 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   s_open_time              629 non-null    object
#  1   open_time                629 non-null    int64
#  2   ticker                   629 non-null    object
#  3   open                     629 non-null    float64
#  4   high                     629 non-null    float64
#  5   low                      629 non-null    float64
#  6   close                    629 non-null    float64
#  7   adj_close                629 non-null    float64
#  8   volume                   629 non-null    int64
#  9   type                     629 non-null    object
#  10  ema_adj_close_200p       430 non-null    float32
#  11  ema_adj_close_200p_diff  430 non-null    float32
#  12  ema_close_200p           430 non-null    float32
#  13  ema_close_200p_diff      430 non-null    float32
#  14  rsi                      615 non-null    float64
# dtypes: float32(4), float64(6), int64(2), object(3)
# memory usage: 64.0+ KB
# Ticker: BRSR6.SA - Shape (3951, 15)
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3951 entries, 0 to 3950
# Data columns (total 15 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   s_open_time              3951 non-null   object
#  1   open_time                3951 non-null   int64
#  2   ticker                   3951 non-null   object
#  3   open                     3951 non-null   float64
#  4   high                     3951 non-null   float64
#  5   low                      3951 non-null   float64
#  6   close                    3951 non-null   float64
#  7   adj_close                3951 non-null   float64
#  8   volume                   3951 non-null   int64
#  9   type                     3951 non-null   object
#  10  ema_adj_close_200p       3752 non-null   float32
#  11  ema_adj_close_200p_diff  3752 non-null   float32
#  12  ema_close_200p           3752 non-null   float32
#  13  ema_close_200p_diff      3752 non-null   float32
#  14  rsi                      3937 non-null   float64
# dtypes: float32(4), float64(6), int64(2), object(3)
# memory usage: 401.4+ KB
# /home/marcelo/des/xpe_projeto_aplicado/src/utils.py:127: RuntimeWarning: Mean of empty slice.
#   a[n] = x[1: n + 1].mean()
# /home/marcelo/des/xpe_projeto_aplicado/.env/lib64/python3.11/site-packages/numpy/core/_methods.py:129: RuntimeWarning: invalid value encountered in scalar divide
#   ret = ret.dtype.type(ret / rcount)
